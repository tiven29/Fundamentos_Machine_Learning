# %% [markdown]
# ![Logo](img/ITQ.png)
# ## Nombre: Elvis Pachacama
# ### Fecha: 21/05/2026

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
#Creao una variable de tipo lista vacia
nivel_estudios = []
#CReando o ingresando a mi lista la varaible Secuariada  y creo 110 veces secundarria
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Secundaria' 'Master' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Master'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Doctorado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Master' 'Grado' 'Master' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Doctorado' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Master' 'Secundaria' 'Master' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Doctorado' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria'
#  'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Doctorado' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Master' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Grado' 'Master'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Master' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Master' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Doctorado' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Secundaria' 'Master'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Master'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Doctorado' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Master'
#  'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Grado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información
